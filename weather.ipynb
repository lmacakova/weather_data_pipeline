# %% [markdown]
# # Weather - assesment tasks

# %% [markdown]
# ### Steps

# %% [markdown]
# ##### Task 1: Create Directory Structure
# I opened the codespace of my repository called computer infrastructure and with command mkdir I created a directory called data at the root of the repository. Inside of directory data, I created 2 subdirectories called timestamps and weather with command mkdir.

# %% [markdown]
# ##### Task 2: Timestamps
#  In the data/timestamps directory, I created file now.txt with command date >> now.txt. I repeated this step 10 times. Then I checked content of file now.txt with command more. I got 11 timestamps in the file now.txt.

# %% [markdown]
# ##### Task 3: Formatting Timestamps
# With command date +"%Y%m%d_%H%M%S" >> formatted.txt, I created file formatted.txt containing timestamp in required format of YYYYmmdd_HHMMSS.

# %% [markdown]
# ##### Task 4: Create Timestamped Files
# With command touch `` ` ``date +"%Y%m%d_%H%M%S".txt `` ` ``, I created a file called 20241108_120500.txt

# %% [markdown]
# ##### Task 5: Download Today's Weather Data
# With command wget -O weather.json https://prodapi.metweb.ie/observations/athenry/today, I downloaded weather data for the Athenry weather station from Met Eireann.

# %% [markdown]
# ##### Task 6: Timestamp the Data
# I modified command from task 6 as - wget -O data/weather/`` ` ``date +"%Y%m%d_%H%M%S_Athenry.json"`` ` `` https://prodapi.metweb.ie/observations/athenry/today - to download current weather data with timestamp as a name of file.

# %% [markdown]
# ##### Task 7: Write the Script
# I wrote script called weather.sh, at the root of my repository:
#
# #! /bin/bash
#
# wget -O data/weather/`` ` ``date +"%Y%m%d_%H%M%S_Athenry.json"`` ` `` https://prodapi.metweb.ie/observations/athenry/today
#
# This script automates process from Task 6. I made the script executable with command chmod u+x ./weather.sh.

# %% [markdown]
# ##### Task 8: Notebook
# I created this notebook with command touch weather.ipynb.
#
# In paragraphs above is the short explanation of how tasks from 1 to 7 were completed.
# I used these commands:
# - mkdir - creating directories, if they do not already exist.
# - touch - updating access and modification times of each file to the current times. It can be used for creating new file as touch name_of_file.suffix
# - date - printing or setting the date and time
# - wget - non-interactive network downloading
# - more - for view of chosen text file in the command line
# - man - displaying user manual for any command that can be run in the command line
# - chmod - changing file mode
# - pwd, ls, cd to move among folders and files

# %% [markdown]
# ##### Task 9: Pandas

# %%
import json
import pandas as pd

data=pd.read_json("data/weather/weather.json")
data
# Out:
#        name  temperature symbol weatherDescription               text  \
# 0   Athenry           12    04n             Cloudy           "Cloudy"
# 1   Athenry           12    04n             Cloudy           "Cloudy"
# 2   Athenry           12    15n         Fog / Mist             "Mist"
# 3   Athenry           12    15n         Fog / Mist             "Mist"
# 4   Athenry           12    15n         Fog / Mist             "Mist"
# 5   Athenry           12    15n         Fog / Mist             "Mist"
# 6   Athenry           12    15n         Fog / Mist             "Mist"
# 7   Athenry           12    04n             Cloudy           "Cloudy"
# 8   Athenry           12    04d             Cloudy           "Cloudy"
# 9   Athenry           12    04d             Cloudy           "Cloudy"
# 10  Athenry           12    04d             Cloudy           "Cloudy"
# 11  Athenry           13    04d             Cloudy           "Cloudy"
# 12  Athenry           13    04d             Cloudy           "Cloudy"
# 13  Athenry           14    04d             Cloudy           "Cloudy"
# 14  Athenry           15    04d             Cloudy           "Cloudy"
# 15  Athenry           14    04d             Cloudy           "Cloudy"
# 16  Athenry           14    04d             Cloudy           "Cloudy"
# 17  Athenry           14    04n             Cloudy           "Cloudy"
# 18  Athenry           14    04n             Cloudy           "Cloudy"
# 19  Athenry           13    04n             Cloudy           "Cloudy"
# 20  Athenry           13    46n        Light rain    "Light Drizzle "
# 21  Athenry           13    46n        Light rain    "Heavy Drizzle "
# 22  Athenry           12    46n        Light rain   "Recent Drizzle "
# 23  Athenry           12    04n             Cloudy           "Cloudy"
#
#     windSpeed windGust cardinalWindDirection  windDirection  humidity  \
# 0          13        -                     E             90        92
# 1          15        -                     E             90        93
# 2          11        -                     E             90        95
# 3          11        -                     E             90        95
# 4          11        -                    SE            135        93
# 5           9        -                    SE            135        92
# 6          11        -                    SE            135        92
# 7           9        -                    SE            135        92
# 8          11        -                    SE            135        93
# 9          11        -                    SE            135        92
# 10         11        -                    SE            135        91
# 11          7        -                    SE            135        91
# 12          9        -                    SE            135        89
# 13         11        -                    SE            135        88
# 14         11        -                    SE            135        83
# 15          6        -                    SE            135        85
# 16         15        -                    SE            135        84
# 17          7        -                     S            180        85
# 18         13        -                     S            180        87
# 19          9        -                    SE            135        89
# 20          9        -                     S            180        91
# 21          7        -                     S            180        96
# 22          6        -                     S            180        95
# 23          4        -                     S            180        95
#
#     rainfall  pressure   dayName       date reportTime
# 0       0.00      1020  Saturday 2024-09-11      00:00
# 1       0.00      1020  Saturday 2024-09-11      01:00
# 2       0.00      1020  Saturday 2024-09-11      02:00
# 3       0.00      1020  Saturday 2024-09-11      03:00
# 4       0.00      1020  Saturday 2024-09-11      04:00
# 5       0.00      1020  Saturday 2024-09-11      05:00
# 6       0.00      1020  Saturday 2024-09-11      06:00
# 7       0.00      1020  Saturday 2024-09-11      07:00
# 8       0.00      1020  Saturday 2024-09-11      08:00
# 9       0.00      1021  Saturday 2024-09-11      09:00
# 10      0.00      1021  Saturday 2024-09-11      10:00
# 11      0.00      1021  Saturday 2024-09-11      11:00
# 12      0.00      1020  Saturday 2024-09-11      12:00
# 13      0.00      1020  Saturday 2024-09-11      13:00
# 14      0.00      1019  Saturday 2024-09-11      14:00
# 15      0.00      1019  Saturday 2024-09-11      15:00
# 16      0.00      1019  Saturday 2024-09-11      16:00
# 17      0.00      1020  Saturday 2024-09-11      17:00
# 18      0.00      1020  Saturday 2024-09-11      18:00
# 19      0.00      1020  Saturday 2024-09-11      19:00
# 20      0.01      1020  Saturday 2024-09-11      20:00
# 21      1.40      1020  Saturday 2024-09-11      21:00
# 22      0.01      1021  Saturday 2024-09-11      22:00
# 23      0.10      1021  Saturday 2024-09-11      23:00
